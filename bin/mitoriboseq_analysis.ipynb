# %%
import os
import pandas as pd
from importlib import reload
import matplotlib.pyplot as plt
import seaborn as sns
import utils

PATH = os.path.dirname(os.getcwd())

mito_cumsum_table_hct = pd.read_csv(os.path.join(PATH, 'data', 'mitoriboseq_analysis', 'hct_116', 'tables', 'mito_cumsum_table.csv'))
mito_cumsum_table_hek = pd.read_csv(os.path.join(PATH, 'data', 'mitoriboseq_analysis', 'hek', 'tables', 'mito_cumsum_table.csv'))
cyto_cumsum_table_hct = pd.read_csv(os.path.join(PATH, 'data', 'mitoriboseq_analysis', 'hct_116_cytoribo', 'tables', 'mito_cumsum_table.csv'))
mito_cumsum_table_hek_ini = pd.read_csv(os.path.join(PATH, 'data', 'mitoriboseq_analysis', 'hek_ini', 'tables', 'mito_cumsum_table.csv'))
mito_cumsum_table_hek_ini_mito_settings = pd.read_csv(os.path.join(PATH, 'data', 'mitoriboseq_analysis', 'hek_ini_mito_setting', 'mito_cumsum_table.csv'))
mito_cumsum_table_hek_ini_if3 = pd.read_csv(os.path.join(PATH, 'data', 'mitoriboseq_analysis', 'hek_ini_mtif3_ko', 'tables', 'mito_cumsum_table.csv'))
# Unite them
mito_cumsum_table = pd.concat([mito_cumsum_table_hct, mito_cumsum_table_hek, mito_cumsum_table_hek_ini, mito_cumsum_table_hek_ini_if3], ignore_index=True)
reload(utils)
# Out:
# <module 'utils' from 'c:\\Users\\shtolz\\Desktop\\multi_function_review\\bin\\utils.py'>

# %%
#mito_cumsum_table_hct['gene_id'] = utils.enst_to_symbol_batch(mito_cumsum_table_hct['transcript_id'])
#mito_cumsum_table['gene_id'] = utils.enst_to_symbol_batch(mito_cumsum_table['transcript_id'])
#cyto_cumsum_table_hct['gene_id'] = utils.enst_to_symbol_batch(cyto_cumsum_table_hct['transcript_id'])

mito_cumsum_table_hek_ini['gene_id'] = utils.enst_to_symbol_batch(mito_cumsum_table_hek_ini['transcript_id'])
mito_cumsum_table_hek_ini_mito_settings['gene_id'] = utils.enst_to_symbol_batch(mito_cumsum_table_hek_ini_mito_settings['transcript_id'])
mito_cumsum_table_hek_ini_if3['gene_id'] = utils.enst_to_symbol_batch(mito_cumsum_table_hek_ini_if3['transcript_id'])
mito_cumsum_table
# Out:
# Input sequence provided is already in string format. No operation performed
# Input sequence provided is already in string format. No operation performed
# 13 input query terms found dup hits:	[('ENST00000361390', 957), ('ENST00000361453', 1044), ('ENST00000361624', 1542), ('ENST00000361739',
# 2775 input query terms found no hit:	['gene_MOTSc', 'gene_MOTSc', 'gene_MOTSc', 'gene_MOTSc', 'gene_MOTSc', 'gene_MOTSc', 'gene_MOTSc', '
# Input sequence provided is already in string format. No operation performed
# Input sequence provided is already in string format. No operation performed
# 13 input query terms found dup hits:	[('ENST00000361390', 957), ('ENST00000361453', 1044), ('ENST00000361624', 1542), ('ENST00000361739',
# 2775 input query terms found no hit:	['gene_MOTSc', 'gene_MOTSc', 'gene_MOTSc', 'gene_MOTSc', 'gene_MOTSc', 'gene_MOTSc', 'gene_MOTSc', '
# Input sequence provided is already in string format. No operation performed
# ...

# %%
mito_cumsum_table_hct.to_csv(os.path.join(PATH, 'data', 'mitoriboseq_analysis', 'hct_116', 'tables', 'mito_cumsum_table_with_gene_ids.csv'), index=False)
mito_cumsum_table.to_csv(os.path.join(PATH, 'data', 'mitoriboseq_analysis', 'combined', 'mito_cumsum_table_with_gene_ids.csv'), index=False)
cyto_cumsum_table_hct.to_csv(os.path.join(PATH, 'data', 'mitoriboseq_analysis', 'hct_116_cytoribo', 'tables', 'mito_cumsum_table_with_gene_ids.csv'), index=False)
mito_cumsum_table_hek.to_csv(os.path.join(PATH, 'data', 'mitoriboseq_analysis', 'hek', 'tables', 'mito_cumsum_table_with_gene_ids.csv'), index=False)
mito_cumsum_table_hek_ini.to_csv(os.path.join(PATH, 'data', 'mitoriboseq_analysis', 'hek_ini', 'tables', 'mito_cumsum_table_with_gene_ids.csv'), index=False)
mito_cumsum_table_hek_ini_mito_settings.to_csv(os.path.join(PATH, 'data', 'mitoriboseq_analysis', 'hek_ini_mito_setting', 'tables', 'mito_cumsum_table_with_gene_ids.csv'), index=False)
mito_cumsum_table_hek_ini_if3.to_csv(os.path.join(PATH, 'data', 'mitoriboseq_analysis', 'hek_ini_mtif3_ko', 'tables', 'mito_cumsum_table_with_gene_ids.csv'), index=False)

# %%
# Show the codon counts per transcript
sns.relplot(data=mito_cumsum_table, x='codon_index', y='RPM_normgene', kind='line', height=6, aspect=2, col='gene_id', col_wrap=3, sharey=False, sharex = False)
